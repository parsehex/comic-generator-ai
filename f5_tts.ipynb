# %% [markdown]
# Use
# ```
# python -m f5_tts_mlx.generate --text "The quick brown fox jumped over the lazy dog."
# ```
# to generate from CLI.

# %%
from src.f5tts import generate
from src.utils import displayAudio

text = 'This is some test text. It sounds pretty good, right?'
out_path = 'output.wav'

generate(text, output_path=out_path)
displayAudio(path=out_path)
# Out:
# Fetching 2 files: 100%|██████████| 2/2 [00:00<00:00, 55553.70it/s]
# Got reference audio with duration: 5.33 seconds
# Using duration of 5.62 seconds for generated speech.
# Generating 1027 total frames of audio...
# Fetching 2 files: 100%|██████████| 2/2 [00:00<00:00, 13617.87it/s]
# Generated 5.65 seconds of audio in 0:01:02.626099.
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
